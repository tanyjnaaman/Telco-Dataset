# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
import numpy as np

# %%
filename = "finantier_ds_technical_test_dataset.csv"
df = pd.read_csv(filename, index_col = False)

# %% [markdown]
# # Cleaning the data
# A cursory look at the dataset suggests that customerID is the primary key, gender, Senior Citizen, Partner, Dependents, PhoneService, InternetService, TechSupport, StreamingTV and StreamingMovies are categorical variables that should be non-null. PhoneService and MultipleLines are correlated, as are InternetService, OnlineSecurity and DeviceProtection and other internet-dependent services in the same way, as are Contract, PaperlessBilling, PaymentMethod and MonthlyCharges. But because all members should be on contract (since we're doing default prediction), all customers should be on contract. So that column should not be null either.
#
# These create the following constraints:
# 1. All columns should be non-null, except for MultipleLines - which are null when PhoneService is No, OnlineSecurity and DeviceProtection - which are null when InternetService is No.
# 2. All columns should take their valid values: gender should only have Male and Female etc.
#
# We can now check for these constraints and fix (if possible) or remove rows that violate these constraints. We should also check for empty strings and replace them with NaN values.

# %%
df = df.replace(' ', np.nan)

# %%
'''
remove all rows with NaN customerID, gender, senior citizen, dependents, 
tenure, contract, paperlessBilling, PaymentMethod, MonthlyCharges, 
TotalCharges, Default
'''
df = df.dropna(subset=['customerID', 
                      'gender', 
                      'SeniorCitizen', 
                      'Partner',
                      'Dependents', 
                      'tenure',
                      'Contract',
                      'PaperlessBilling',
                      'PaymentMethod',
                      'MonthlyCharges',
                      'TotalCharges',
                      'Default'])

df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1     7590-VHVEG  Female            0.0     Yes         No     1.0
# 2     5575-GNVDE    Male            0.0      No         No    34.0
# 3     3668-QPYBK    Male            0.0      No         No     2.0
# 4     7795-CFOCW    Male            0.0      No         No    45.0
# 5     9237-HQITU  Female            0.0      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7043  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7044  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7045  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7046  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7047  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1              No  No phone service             DSL             No  ...
# ...

# %%
'''
Check if correlations are true. 
e.g. if MultipleLines says 'no phone service', then phoneService should be 'No'
'''

# phoneService dependent columns
df.drop(df[(df['PhoneService'] == "Yes") & (df['MultipleLines'] == "No phone service")
  | (df["InternetService"] == "Yes") & (
      (df["OnlineSecurity"] == "No internet service")
      | (df["OnlineSecurity"] == "No internet service")
      | (df["DeviceProtection"] == "No internet service")
      | (df["TechSupport"] == "No internet service")
      | (df["StreamingTV"] == "No internet service")
      | (df["StreamingMovies"] == "No internet service"))].index)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1     7590-VHVEG  Female            0.0     Yes         No     1.0
# 2     5575-GNVDE    Male            0.0      No         No    34.0
# 3     3668-QPYBK    Male            0.0      No         No     2.0
# 4     7795-CFOCW    Male            0.0      No         No    45.0
# 5     9237-HQITU  Female            0.0      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7043  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7044  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7045  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7046  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7047  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1              No  No phone service             DSL             No  ...
# ...

# %%
df.to_csv('cleaned_default.csv')

# %% [markdown]
# At this point, we can convert the categorical variables into categorical encodings.

# %%
# convert string columns to numeric if needed
df["TotalCharges"] = pd.to_numeric(df['TotalCharges'])

# convert senior citizen to categorical
df = df.astype({"SeniorCitizen": 'object'})

# convert categorical columns to numbers
cat_columns = df.select_dtypes(['object']).columns
cts_columns = df.select_dtypes(['float64']).columns

df[cat_columns] = df[cat_columns].apply(lambda x : x.astype('category').cat.codes)
df
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 1           5365       0              0        1           0     1.0
# 2           3953       1              0        0           0    34.0
# 3           2558       1              0        0           0     2.0
# 4           5524       1              0        0           0    45.0
# 5           6500       0              0        0           0     2.0
# ...          ...     ...            ...      ...         ...     ...
# 7043        4843       1              0        1           1    24.0
# 7044        1524       0              0        1           1    72.0
# 7045        3358       0              0        1           1    11.0
# 7046        5923       1              1        1           0     4.0
# 7047        2221       1              0        0           0    66.0
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# 1                0              1                0               0
# ...

# %% [markdown]
# # Investigating the data
# ## Descriptive statistics

# %%
# descriptive statistics
df.astype('object').describe()
# Out:
#         customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# count         7032    7032           7032     7032        7032  7032.0
# unique        7032       2              2        2           2    72.0
# top              0       1              0        0           0     1.0
# freq             1    3549           5890     3639        4933   613.0
#
#         PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# count           7032           7032             7032            7032
# unique             2              3                3               3
# top                1              0                1               0
# freq            6352           3385             3096            3497
#
#         OnlineBackup  DeviceProtection  TechSupport  StreamingTV  \
# count           7032              7032         7032         7032
# unique             3                 3            3            3
# ...

# %%
# descriptive statistics
df.describe()
# Out:
#         customerID       gender  SeniorCitizen      Partner   Dependents  \
# count  7032.000000  7032.000000    7032.000000  7032.000000  7032.000000
# mean   3515.500000     0.504693       0.162400     0.482509     0.298493
# std    2030.107879     0.500014       0.368844     0.499729     0.457629
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%    1757.750000     0.000000       0.000000     0.000000     0.000000
# 50%    3515.500000     1.000000       0.000000     0.000000     0.000000
# 75%    5273.250000     1.000000       0.000000     1.000000     1.000000
# max    7031.000000     1.000000       1.000000     1.000000     1.000000
#
#             tenure  PhoneService  MultipleLines  InternetService  \
# count  7032.000000   7032.000000    7032.000000      7032.000000
# mean     32.421786      0.903299       0.940557         0.872582
# std      24.545260      0.295571       0.948627         0.737271
# ...

# %%
# pairwise correlation
import seaborn as sns
corr_matrix = df.corr()
sns.heatmap(corr_matrix)
corr_matrix
# Out:
#                   customerID    gender  SeniorCitizen   Partner  Dependents  \
# customerID          1.000000  0.006235      -0.002368 -0.026509   -0.011871
# gender              0.006235  1.000000      -0.001819 -0.001379    0.010349
# SeniorCitizen      -0.002368 -0.001819       1.000000  0.016957   -0.210550
# Partner            -0.026509 -0.001379       0.016957  1.000000    0.452269
# Dependents         -0.011871  0.010349      -0.210550  0.452269    1.000000
# tenure              0.007209  0.005285       0.015683  0.381912    0.163386
# PhoneService       -0.006987 -0.007515       0.008392  0.018397   -0.001078
# MultipleLines       0.004497 -0.006908       0.146287  0.142717   -0.024975
# InternetService    -0.012335 -0.002236      -0.032160  0.000513    0.044030
# OnlineSecurity      0.013740 -0.014899      -0.127937  0.150610    0.151198
# OnlineBackup       -0.002960 -0.011920      -0.013355  0.153045    0.090231
# ...

# %%
pd.set_option("display.max_columns", None)

# %% [markdown]
# ## PCA and k-Means
# Principal component analysis allows us to visualise the distribution of values by compressing the dimensions into 2 dimensions. We can use it to see how tightly default behaviours are clustered. With all features, there are no discernable clusters that can be observed easily.

# %%
# get unique values for each desired

columns = df.columns
column_vals = {}
for col in columns:
    column_vals[col] = df[col].unique()

column_vals

def embed(col, column_vals, embed_dim):
    return layers.Embedding(len(column_vals[col]),2)

# %%
def encodeCat_normalizeCts(df, cat_columns, cts_columns):
   
    # split data set into continuous and categorical, and encode/normalize
    df_model_cat = pd.DataFrame()
    df_model_cts = pd.DataFrame()

    # one hot encode categorical variables
    for col in cat_columns:
        if col != "customerID" and col != 'Default' and col in df.columns:
            temp = pd.get_dummies(df[col], prefix = col)
            df_model_cat = pd.concat([df_model_cat, temp], axis = 1)

    # append and standardize continuous variables
    have_cts = False
    cts_columns = df.select_dtypes(['float64']).columns
    for col in cts_columns:
        if col in df.columns:
            df_model_cts = pd.concat([df_model_cts, df[col]], axis = 1)
            have_cts = True

    X_cat = df_model_cat
    X_cts = df_model_cts
    Y = df["Default"].to_numpy().reshape(df.shape[0], 1)
    
    if have_cts:
        from sklearn.preprocessing import StandardScaler, MinMaxScaler
        s = StandardScaler()
        X_cts = s.fit_transform(X_cts)
    
    # concatenate standardized continuous and categorical
    return np.concatenate([X_cat, X_cts, Y], axis = 1)

# %%
def PCAandKmeans_2dim(x):
    # scale the data
    from sklearn.preprocessing import StandardScaler
    x = StandardScaler().fit_transform(x)

    # fitting with PCA
    from sklearn.decomposition import PCA
    pca = PCA(n_components = 2)
    principalComponents = pca.fit_transform(x)

    # fitting with k-means
    from sklearn.cluster import KMeans
    kmeans = KMeans(n_clusters = 2).fit(x)

    #visualisation
    principalDf = pd.DataFrame(data = principalComponents, columns = ['PC 1', 'PC 2'])
    colors = np.where(df['Default'] == 1, 'r', 'b')
    colors_kmeans = np.where(kmeans.labels_ == 1, 'y', 'g')
    principalDf.plot.scatter('PC 1', 'PC 2', s = 5, c = colors)
    plt.title("PCA, labelled by default or not")
    principalDf.plot.scatter('PC 1', 'PC 2', s = 5, c = colors_kmeans)
    plt.title("PCA, labelled by k-means clustering")
    plt.show()
    
    evr = pca.explained_variance_ratio_
    print(f'PCA explained variance ratio is: {evr}')

# %%
PCAandKmeans_2dim(encodeCat_normalizeCts(df, cat_columns, cts_columns))
# Out:
# PCA explained variance ratio is: [0.24442219 0.13248416]

# %% [markdown]
# ### Separation by correlation

# %% [markdown]
# One approach to seeing patterns underlying the data is to separate the sample according to our observations from studying the correlations and see if any clustering patterns can be observed.
#
# I arbitrarily choose features with correlation >= 0.20 with the default outcome.
# The lack of a clear split here suggests that there might be more complex relationships present, like variables not being independent.

# %%
focus = [
    "tenure",
    "OnlineSecurity",
    "OnlineBackup",
    "TechSupport",
    "Contract",
    "PaperlessBilling",
    "TotalCharges",
    "MonthlyCharges",
    "Contract",
    "Default"
]
df_focused = df[focus]

PCAandKmeans_2dim(encodeCat_normalizeCts(df_focused, cat_columns, cts_columns))
# Out:
# PCA explained variance ratio is: [0.32973911 0.26056005]

# %% [markdown]
# ### Qualitative inspection of distributions in the data
# Another way is to plot the distributions of each feature for default vs. non-default users and compare them. It's more labour intensive, but it'll give me a better feel for what's going on.
#
# An examination of the histograms suggest that if a person is more likely to default if:
# 1. is a senior citizen
# 2. not partner
# 3. no dependents
# 4. has a shorter tenure
# 5. has no online backup, device protection, tech support, streaming tv or movies
# 6. has shorter contract
# 7. tend to use mailed check
# 8. has higher monthly fees
#
# This intuitive examination suggests a decision tree might be able to separate and predict relatively well.

# %%
# histograms
for col in df:
    plt.figure()
    df[df['Default'] == 1][[col]].hist()
    df[df['Default'] == 0][[col]].hist()
    plt.show()
    plt.clf()

# %% [markdown]
# # Preprocessing
#
# ## What I intend to do
# Before training models, we must split the data into train and test sets, encode any categorical variables and normalize continuous ones.
#
# I observed most continuous distributions to be skewed and a log-transformation will probably help. While such transformations do not really help models like decision trees, they are important to more sensitive models like neural networks.
#
# Also, this dataset is class-imbalanced, with a ratio of about 1:3. We could consider oversampling, but pure duplication of samples may or may not be useful. I'm not sure. So I will prepare a dataset that is oversampled, one that is balanced by undersampling the dominant class.
#
# Lastly, I will convert the insights we observed from the continuous variables earlier into categorical variables. Specifically, that individuals with a higher monthly fee and shorter tenure are more likely to default. I will use the median as a benchmark - if longer tenure than median, then considered long tenure, else short tenure. This feature will be included in both oversampled and balanced dataset.
#
# Then I will save them as .csv files and develop the models after.
#
#
# ## Engineering features

# %%
# high monthly charges
median = df["MonthlyCharges"].median()
df["HighMonthlyCharges"] = df.apply(lambda row : 1 if row.MonthlyCharges > median else 0, axis = 1)

# short tenure
median = df["tenure"].median()
df["ShortTenure"] = df.apply(lambda row : 1 if row.tenure < median else 0, axis = 1)

# save
df.to_csv('cleanedAndEngineered.csv')
df
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 1           5365       0              0        1           0     1.0
# 2           3953       1              0        0           0    34.0
# 3           2558       1              0        0           0     2.0
# 4           5524       1              0        0           0    45.0
# 5           6500       0              0        0           0     2.0
# ...          ...     ...            ...      ...         ...     ...
# 7043        4843       1              0        1           1    24.0
# 7044        1524       0              0        1           1    72.0
# 7045        3358       0              0        1           1    11.0
# 7046        5923       1              1        1           0     4.0
# 7047        2221       1              0        0           0    66.0
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# 1                0              1                0               0
# ...

# %% [markdown]
# ## Balancing by undersampling

# %%
# balance the dataset
n_neg = len(df[df["Default"] == 0])
n_pos = len((df[df["Default"] == 1]))
df_neg = df[df["Default"] == 0].sample(n_pos)
df_pos = df[df["Default"] == 1]
df_balanced = pd.concat([df_neg, df_pos])

# save
df_balanced.to_csv('cleanedAndEngineered_balanced.csv')
df_balanced
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 2773         984       0              0        0           0    12.0
# 5113        5534       0              0        0           0    23.0
# 2217        5729       1              0        0           0    10.0
# 1589        6968       0              1        0           0    65.0
# 2284        3783       1              1        0           0    72.0
# ...          ...     ...            ...      ...         ...     ...
# 7026        1154       1              0        0           0    12.0
# 7031        6190       0              0        0           0     9.0
# 7037        4883       1              1        0           0     1.0
# 7039         437       0              0        0           0    67.0
# 7046        5923       1              1        1           0     4.0
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# 2773             1              0                2               1
# ...

# %% [markdown]
# ## Balancing by oversampling
# There are approximately thrice as many non-default observations, so a simple way is to undersample by 2/3, and over sample by doubling and meet in the middle. This has the nice property of using more of the data while avoiding too much duplication of the underepresented class, though I will be looking out for issues with a model memorizing answers.

# %%
df_neg = df[df["Default"] == 0].sample(int(n_neg * 2//3), replace = False)
df_pos = df[df["Default"] == 1].sample(int(n_pos * 2), replace = True)
df_balanced_bothWays = pd.concat([df_neg, df_pos])

# save
df_balanced_bothWays.to_csv('cleanedAndEngineered_balanced_bothWays.csv')
df_balanced_bothWays
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 4684        5832       0              0        1           0    72.0
# 3571        6804       0              0        0           1    53.0
# 4210        4550       0              0        1           1    24.0
# 5563         462       0              0        1           1    72.0
# 429         5757       0              0        0           0    10.0
# ...          ...     ...            ...      ...         ...     ...
# 6130         594       1              0        1           0    13.0
# 2896         335       0              0        0           0     1.0
# 3549        6290       1              0        1           0    31.0
# 1055         879       1              1        0           0    12.0
# 2761        3979       0              0        0           0     1.0
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# 4684             1              2                0               2
# ...
